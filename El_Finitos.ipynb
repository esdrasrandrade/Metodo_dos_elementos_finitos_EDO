# %% [markdown]
# <a href="https://colab.research.google.com/github/esdrasrandrade/Metodo_dos_elementos_finitos_EDO/blob/main/El_Finitos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy.integrate import squad

# %%
#Matriz de Rigidez
dominio = 1.0 #comprimento(b-a)
ne = 4 3 #Número de elementos
nn = ne + 1 #Número de nós
h = dominio/ne

# %%
def L1:
  return 1=h/x

# %%
def L2:
  return x/h
